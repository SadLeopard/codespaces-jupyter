# %% [markdown]
# # Esempio Jupyter Notebook

# %% [markdown]
# Importazioni delle librerie

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
m=5.3 # massa in kg
print('massa = ', m, 'kg')

math.sin(1)
# Out:
# massa =  5.3 kg
# 0.8414709848078965

# %% [markdown]
# # Esempio matlotlib

# %%
x=np.linspace(0,2*np.pi,1000)
y=np.sin(x)
z=np.cos(x)

plt.plot(x,y,x,z)
plt.plot(x,y*np.exp(-0.2*x))
plt.grid()
# plt.show() # non necessario in jup
